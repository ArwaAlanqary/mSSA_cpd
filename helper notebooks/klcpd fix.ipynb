# %%
import sys
sys.path.append('../algorithms/klcpd/')
from data_loader import DataLoader
import matplotlib.pyplot as plt
import numpy as np
import sklearn.metrics

# %%
fp_list, tp_list, thresholds = sklearn.metrics.roc_curve(data.trn_set['L'], data.trn_set['L'])
precision = tp_list /(fp_list+ tp_list)
recall = tp_list /(fp_list+ tp_list)


2 * (precision * recall) / (precision + recall)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide
# array([nan, 1. , 0.5])

# %%
fp_list, tp_list, thresholds
# Out:
# (array([0., 0., 1.]), array([0., 1., 1.]), array([2., 1., 0.], dtype=float32))

# %%
data = DataLoader('../data/synth/energy',25, trn_ratio=0.4, val_ratio=0.7)
# Out:
# n_trn  40375 n_val  30300 n_tst  30300

# %%
# Out:
# {'X_p': tensor([[[ 0.0000],
#           [ 7.7325],
#           [10.2973],
#           ...,
#           [-1.0371],
#           [-0.5521],
#           [ 0.8757]],
#
#          [[ 7.7325],
#           [10.2973],
#           [11.6808],
#           ...,
#           [-0.5521],
#           [ 0.8757],
#           [ 3.1923]],
#
#          [[10.2973],
#           [11.6808],
#           [11.3281],
#           ...,
#           [ 0.8757],
#           [ 3.1923],
#           [ 5.8134]],
#
#          ...,
#
#          [[ 1.9942],
#           [ 1.3208],
#           [ 1.0688],
#           ...,
#           [-0.4208],
#           [-0.1452],
#           [ 0.2987]],
#
#          [[ 1.3208],
#           [ 1.0688],
#           [ 0.2768],
#           ...,
#           [-0.1452],
#           [ 0.2987],
#           [ 0.2383]],
#
#          [[ 1.0688],
#           [ 0.2768],
#           [-0.0648],
#           ...,
#           [ 0.2987],
#           [ 0.2383],
#           [ 0.4667]]]),
# ...

# %%
data = sio.loadmat('../../klcpd_code/data/beedance/beedance-1.mat')
cps = np.nonzero(data['L'])[0]
# data = pd.read_csv('../data/yahoo/A4Benchmark-TS11_ts.csv', header = None)
# data_l = pd.read_csv('../data/yahoo/A4Benchmark-TS11_labels.csv', header = None)
# cps = data_l.values[1:,0]

data
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: posix, Created on: Wed Nov  1 15:32:43 2017',
#  '__version__': '1.0',
#  '__globals__': [],
#  'Y': array([[0.34505421, 0.76464539, 0.54221329],
#         [0.32433136, 0.77659554, 0.47098108],
#         [0.30748942, 0.77960098, 0.4279893 ],
#         ...,
#         [0.6162483 , 0.21170825, 0.36854878],
#         [0.6050455 , 0.21422565, 0.68399638],
#         [0.62507353, 0.19284757, 0.30645727]]),
#  'L': array([[0],
#         [0],
#         [0],
#         ...,
#         [0],
#         [0],
#         [0]])}

# %%
# %matplotlib notebook
plt.figure(figsize = (10,2))
for p in cps:
    plt.axvline(p, linestyle = 'dashed', c= 'k')
plt.plot(data['Y'][:,0])
plt.xlabel('time')
plt.ylabel('value')
# Out:
# <img src="data:image/png;base64,..." width="1000">
# Text(0, 0.5, 'value')

# %% [markdown]
# # KLCPD

# %%
import sys
import os
os.chdir('../algorithms/')
from klcpd_ import KLCPD

# %%
model = KLCPD()
